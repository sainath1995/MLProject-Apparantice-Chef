# %% [markdown]
# <center>
# <h1>Data Analysis using feature treatment, variable analysis Methods</h1>
#  Understanding the dataset features through feature treatment, variable analysis and exploratory analysis.

# %%
#1ST SECTION EXPLORATORY DATA ANALYSIS
#importing dataset to explore
import pandas as pd
import numpy as np

file = "Apprentice_Chef_Dataset.xlsx"

chef = pd.read_excel(file)



pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
chef.head(n = 10)
# Out:
#    REVENUE  CROSS_SELL_SUCCESS                              NAME                                     EMAIL FIRST_NAME  FAMILY_NAME  TOTAL_MEALS_ORDERED  UNIQUE_MEALS_PURCH  CONTACTS_W_CUSTOMER_SERVICE  PRODUCT_CATEGORIES_VIEWED  AVG_TIME_PER_SITE_VISIT  MOBILE_NUMBER  CANCELLATIONS_BEFORE_NOON  CANCELLATIONS_AFTER_NOON  TASTES_AND_PREFERENCES  PC_LOGINS  MOBILE_LOGINS  WEEKLY_PLAN  EARLY_DELIVERIES  LATE_DELIVERIES  PACKAGE_LOCKER  REFRIGERATED_LOCKER  FOLLOWED_RECOMMENDATIONS_PCT  AVG_PREP_VID_TIME  LARGEST_ORDER_SIZE  MASTER_CLASSES_ATTENDED  MEDIAN_MEAL_RATING  AVG_CLICKS_PER_VISIT  TOTAL_PHOTOS_VIEWED
# ...

# %% [markdown]
# Using info() to undestand the complete information of the dataset.

# %%
#Checking info of the dataset
chef.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1946 entries, 0 to 1945
# Data columns (total 29 columns):
# REVENUE                         1946 non-null float64
# CROSS_SELL_SUCCESS              1946 non-null int64
# NAME                            1946 non-null object
# EMAIL                           1946 non-null object
# FIRST_NAME                      1946 non-null object
# FAMILY_NAME                     1899 non-null object
# TOTAL_MEALS_ORDERED             1946 non-null int64
# UNIQUE_MEALS_PURCH              1946 non-null int64
# CONTACTS_W_CUSTOMER_SERVICE     1946 non-null int64
# PRODUCT_CATEGORIES_VIEWED       1946 non-null int64
# AVG_TIME_PER_SITE_VISIT         1946 non-null float64
# MOBILE_NUMBER                   1946 non-null int64
# CANCELLATIONS_BEFORE_NOON       1946 non-null int64
# CANCELLATIONS_AFTER_NOON        1946 non-null int64
# TASTES_AND_PREFERENCES          1946 non-null int64
# PC_LOGINS                       1946 non-null int64
# ...

# %% [markdown]
# Missing Value Treatment -
# Finding missing value columns to fill clean the data for acquiring accurate results.

# %%
#checking missing values count
chef.isnull().any().count()
# Out:
# 29

# %%
#checking missing values column
chef.isnull().any().sum()
# Out:
# 1

# %% [markdown]
# We find that from the info() function only the column "FAMILY NAME" has missing values . Since it is an object datatype we fill the values with "NA"

# %%
#filling missing values 

fill_family = 'NA'

#imputing it into fill
chef['FAMILY_NAME'] = chef['FAMILY_NAME'].fillna(fill_family)

# %%
#Cross checking if any missing values are left out.
chef.isnull().any().sum()
# Out:
# 0

# %% [markdown]
# Creating a new chef dataset that has only the columns which are more important for our statistical analysis.

# %%
#Dropping columns
chef_new = chef.drop(['NAME', 'EMAIL' ,'FIRST_NAME', 'FAMILY_NAME',"CROSS_SELL_SUCCESS"],axis = 1)

# %%
#cross checking the columns and entries.
chef_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1946 entries, 0 to 1945
# Data columns (total 24 columns):
# REVENUE                         1946 non-null float64
# TOTAL_MEALS_ORDERED             1946 non-null int64
# UNIQUE_MEALS_PURCH              1946 non-null int64
# CONTACTS_W_CUSTOMER_SERVICE     1946 non-null int64
# PRODUCT_CATEGORIES_VIEWED       1946 non-null int64
# AVG_TIME_PER_SITE_VISIT         1946 non-null float64
# MOBILE_NUMBER                   1946 non-null int64
# CANCELLATIONS_BEFORE_NOON       1946 non-null int64
# CANCELLATIONS_AFTER_NOON        1946 non-null int64
# TASTES_AND_PREFERENCES          1946 non-null int64
# PC_LOGINS                       1946 non-null int64
# MOBILE_LOGINS                   1946 non-null int64
# WEEKLY_PLAN                     1946 non-null int64
# EARLY_DELIVERIES                1946 non-null int64
# LATE_DELIVERIES                 1946 non-null int64
# PACKAGE_LOCKER                  1946 non-null int64
# ...

# %% [markdown]
# Using descriptive statistics method for understanding the type of data for its further analysis.

# %%
#Using descriptive statistcs trying  to understand the quantitative column, and the type of data it holds.

chef_new.loc[:,:].describe([0.2,
                           0.4,
                           0.6,
                           0.8,
                           0.9,
                           1.0]).round(2)
# Out:
#        REVENUE  TOTAL_MEALS_ORDERED  UNIQUE_MEALS_PURCH  CONTACTS_W_CUSTOMER_SERVICE  PRODUCT_CATEGORIES_VIEWED  AVG_TIME_PER_SITE_VISIT  MOBILE_NUMBER  CANCELLATIONS_BEFORE_NOON  CANCELLATIONS_AFTER_NOON  TASTES_AND_PREFERENCES  PC_LOGINS  MOBILE_LOGINS  WEEKLY_PLAN  EARLY_DELIVERIES  LATE_DELIVERIES  PACKAGE_LOCKER  REFRIGERATED_LOCKER  FOLLOWED_RECOMMENDATIONS_PCT  AVG_PREP_VID_TIME  LARGEST_ORDER_SIZE  MASTER_CLASSES_ATTENDED  MEDIAN_MEAL_RATING  AVG_CLICKS_PER_VISIT  TOTAL_PHOTOS_VIEWED
# count  1946.00              1946.00              1946.0                      1946.00                    1946.00                  1946.00        1946.00                    1946.00                   1946.00                 1946.00    1946.00        1946.00      1946.00           1946.00          1946.00         1946.00              1946.00                       1946.00            1946.00             1946.00                  1946.00             1946.00               1946.00              1946.00
# ...

# %% [markdown]
# Catogerizing data to understand more clealrly the data type of features we will be handling

# %%
"""
# CONTINUOUS OR INTERVAL :
followed a cont distribution[rules-ve inf. to + inf. , assume deciomal place,], logarithmic tranformation.

REVENUE
AVG_TIME_PER_SITE_VISIT
AVG_PREP_VID_TIME
FOLLOWED_RECOMMENDATIONS_PCT

# BINARY(limited to 0 or 1)

MOBILE_NUMBER
TASTES_AND_PREFERENCES
PACKAGE_LOCKER
REFRIGERATED_LOCKER

# COUNT- a different approach to feature engineering, number of items.

TOTAL_MEALS_ORDERED
UNIQUE_MEALS_PURCH
PRODUCT_CATEGORIES_VIEWED
CONTACTS_W_CUSTOMER_SERVICE
CANCELLATIONS_BEFORE_NOON
CANCELLATIONS_AFTER_NOON
PC_LOGINS
MOBILE_LOGINS
WEEKLY_PLAN
EARLY_DELIVERIES
LATE_DELIVERIES
LARGEST_ORDER_SIZE
MASTER_CLASSES_ATTENDED
AVG_CLICKS_PER_VISIT
TOTAL_PHOTOS_VIEWED

# CATEGORICAL- either values.(blue or red),(inside , outside)(more than 2 limits)
MEDIAN_MEAL_RATING


# DISCRETE - very unique, origin, (not very accurate,) 

"""
# Out:
# '\n# CONTINUOUS OR INTERVAL :\nfollowed a cont distribution[rules-ve inf. to + inf. , assume deciomal place,], logarithmic tranformation.\n\nREVENUE\nAVG_TIME_PER_SITE_VISIT\nAVG_PREP_VID_TIME\nFOLLOWED_RECOMMENDATIONS_PCT\n\n# BINARY(limited to 0 or 1)\n\nMOBILE_NUMBER\nTASTES_AND_PREFERENCES\nPACKAGE_LOCKER\nREFRIGERATED_LOCKER\n\n# COUNT- a different approach to feature engineering, number of items.\n\nTOTAL_MEALS_ORDERED\nUNIQUE_MEALS_PURCH\nPRODUCT_CATEGORIES_VIEWED\nCONTACTS_W_CUSTOMER_SERVICE\nCANCELLATIONS_BEFORE_NOON\nCANCELLATIONS_AFTER_NOON\nPC_LOGINS\nMOBILE_LOGINS\nWEEKLY_PLAN\nEARLY_DELIVERIES\nLATE_DELIVERIES\nLARGEST_ORDER_SIZE\nMASTER_CLASSES_ATTENDED\nAVG_CLICKS_PER_VISIT\nTOTAL_PHOTOS_VIEWED\n\n# CATEGORICAL- either values.(blue or red),(inside , outside)(more than 2 limits)\nMEDIAN_MEAL_RATING\n\n\n# DISCRETE - very unique, origin, (not very accurate,) \n\n'

# %% [markdown]
# As we can see that for MEDIAN MEAL RATING column, customers are somewhat satisfied with the meal provided.

# %%
#### Categorical variable type analysis
print(f"""

MEDIAN_MEAL_RATING
-------------
{chef_new['MEDIAN_MEAL_RATING'].value_counts().sort_index()}
      
""")
# Out:
# MEDIAN_MEAL_RATING
# -------------
# 1      99
# 2     487
# 3    1087
# 4     260
# 5      13
# Name: MEDIAN_MEAL_RATING, dtype: int64

# %% [markdown]
# From below, it can be clearly seen that most of the customers have provided the mobile number, which could mean a very small percentage is odering through pc logins,and similarly it can be understood that mostly package lockers and refrigirated lockers are not available for many customers.Most customers have already provided information about their tastes and preferences.

# %%
#### Binary data
print(f"""

MOBILE_NUMBER
-------------
{chef_new['MOBILE_NUMBER'].value_counts().sort_index()}
      
TASTES_AND_PREFERENCES
-------------
{chef_new['TASTES_AND_PREFERENCES'].value_counts().sort_index()}
      
PACKAGE_LOCKER
-------------
{chef_new['PACKAGE_LOCKER'].value_counts().sort_index()}
           
      
REFRIGERATED_LOCKER
-------------
{chef_new['REFRIGERATED_LOCKER'].value_counts().sort_index()}
      
""")
# Out:
# MOBILE_NUMBER
# -------------
# 0     238
# 1    1708
# Name: MOBILE_NUMBER, dtype: int64
#
# TASTES_AND_PREFERENCES
# -------------
# 0     556
# 1    1390
# Name: TASTES_AND_PREFERENCES, dtype: int64
#
# PACKAGE_LOCKER
# -------------
# 0    1255
# 1     691
# Name: PACKAGE_LOCKER, dtype: int64
#
#
# REFRIGERATED_LOCKER
# -------------
# 0    1726
# 1     220
# Name: REFRIGERATED_LOCKER, dtype: int64

# %%
import pandas as pd# data science essentials
import seaborn as sns # essential graphical output
import matplotlib.pyplot as plt # enhanced graphical output
import statsmodels.formula.api as smf # regression modeling


# setting pandas print options
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
#not good feature to use -  unique ,prdct viewed,cancellation b4 noon,CANC. AFTER NOON,

# %% [markdown]
# Creating Co-variance matrix to understand the strongest features relevant to the target variable 'REVENUE'

# %%
# creating a (Pearson) correlation matrix
df_corr = chef_new.corr().round(2)


# printing (Pearson) correlations with SalePrice
print(df_corr.loc['REVENUE'].sort_values(ascending = False))
# Out:
# REVENUE                         1.00
# AVG_PREP_VID_TIME               0.64
# MEDIAN_MEAL_RATING              0.61
# TOTAL_MEALS_ORDERED             0.60
# TOTAL_PHOTOS_VIEWED             0.47
# MASTER_CLASSES_ATTENDED         0.45
# LARGEST_ORDER_SIZE              0.44
# AVG_TIME_PER_SITE_VISIT         0.14
# CONTACTS_W_CUSTOMER_SERVICE     0.10
# PRODUCT_CATEGORIES_VIEWED       0.03
# MOBILE_NUMBER                   0.03
# PC_LOGINS                       0.02
# CANCELLATIONS_BEFORE_NOON       0.01
# TASTES_AND_PREFERENCES          0.01
# WEEKLY_PLAN                     0.01
# EARLY_DELIVERIES               -0.00
# REFRIGERATED_LOCKER            -0.00
# LATE_DELIVERIES                -0.01
# PACKAGE_LOCKER                 -0.01
# FOLLOWED_RECOMMENDATIONS_PCT   -0.02
# MOBILE_LOGINS                  -0.02
# CANCELLATIONS_AFTER_NOON       -0.04
# UNIQUE_MEALS_PURCH             -0.06
# AVG_CLICKS_PER_VISIT           -0.55
# Name: REVENUE, dtype: float64

# %% [markdown]
# Printing all column names

# %%
#Creating a file to print all the columns in df format
chef_new_copy = chef_new.copy()

chef_new_copy = chef_new_copy.drop(['REVENUE'],axis = 1)

for val in chef_new_copy:
    print(f"chef_new['{val}'] +")
# Out:
# chef_new['TOTAL_MEALS_ORDERED'] +
# chef_new['UNIQUE_MEALS_PURCH'] +
# chef_new['CONTACTS_W_CUSTOMER_SERVICE'] +
# chef_new['PRODUCT_CATEGORIES_VIEWED'] +
# chef_new['AVG_TIME_PER_SITE_VISIT'] +
# chef_new['MOBILE_NUMBER'] +
# chef_new['CANCELLATIONS_BEFORE_NOON'] +
# chef_new['CANCELLATIONS_AFTER_NOON'] +
# chef_new['TASTES_AND_PREFERENCES'] +
# chef_new['PC_LOGINS'] +
# chef_new['MOBILE_LOGINS'] +
# chef_new['WEEKLY_PLAN'] +
# chef_new['EARLY_DELIVERIES'] +
# chef_new['LATE_DELIVERIES'] +
# chef_new['PACKAGE_LOCKER'] +
# chef_new['REFRIGERATED_LOCKER'] +
# chef_new['FOLLOWED_RECOMMENDATIONS_PCT'] +
# chef_new['AVG_PREP_VID_TIME'] +
# chef_new['LARGEST_ORDER_SIZE'] +
# chef_new['MASTER_CLASSES_ATTENDED'] +
# chef_new['MEDIAN_MEAL_RATING'] +
# chef_new['AVG_CLICKS_PER_VISIT'] +
# chef_new['TOTAL_PHOTOS_VIEWED'] +

# %% [markdown]
# Using statsmodel to output OLS Regression Results and clealry understand which are the most significant feature with respect to the target variable 'Revenue'

# %%
# building a base model and trying to understand which are the relevant features tht

# blueprinting a model type
chef_ols_base_model = smf.ols(formula = """chef_new['REVENUE'] ~
                                                chef_new['TOTAL_MEALS_ORDERED'] +
                                                chef_new['UNIQUE_MEALS_PURCH'] +
                                                chef_new['CONTACTS_W_CUSTOMER_SERVICE'] +
                                                chef_new['PRODUCT_CATEGORIES_VIEWED'] +
                                                chef_new['AVG_TIME_PER_SITE_VISIT'] +
                                                chef_new['MOBILE_NUMBER'] +
                                                chef_new['CANCELLATIONS_BEFORE_NOON'] +
                                                chef_new['CANCELLATIONS_AFTER_NOON'] +
                                                chef_new['TASTES_AND_PREFERENCES'] +
                                                chef_new['PC_LOGINS'] +
                                                chef_new['MOBILE_LOGINS'] +
                                                chef_new['WEEKLY_PLAN'] +
                                                chef_new['EARLY_DELIVERIES'] +
                                                chef_new['LATE_DELIVERIES'] +
                                                chef_new['PACKAGE_LOCKER'] +
                                                chef_new['REFRIGERATED_LOCKER'] +
                                                chef_new['FOLLOWED_RECOMMENDATIONS_PCT'] +
                                                chef_new['AVG_PREP_VID_TIME'] +
                                                chef_new['LARGEST_ORDER_SIZE'] +
                                                chef_new['MASTER_CLASSES_ATTENDED'] +
                                                chef_new['MEDIAN_MEAL_RATING'] +
                                                chef_new['AVG_CLICKS_PER_VISIT'] +
                                                chef_new['TOTAL_PHOTOS_VIEWED'] """,
                                                    data = chef_new)


# telling Python to run the data through the blueprint
results = chef_ols_base_model.fit()


# printing the results
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     chef_new['REVENUE']   R-squared:                       0.640
# Model:                             OLS   Adj. R-squared:                  0.636
# Method:                  Least Squares   F-statistic:                     148.6
# Date:                 Fri, 06 Mar 2020   Prob (F-statistic):               0.00
# Time:                         18:51:12   Log-Likelihood:                -15461.
# No. Observations:                 1946   AIC:                         3.097e+04
# Df Residuals:                     1922   BIC:                         3.110e+04
# Df Model:                           23
# Covariance Type:             nonrobust
# ...
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Using OLS Regression resluts and co-variance matrix, we will be creating the best model and use it for finding R-square values

# %%
import sklearn.linear_model

# %% [markdown]
# Using the stats model we could observe that most relevant features were the ones with p-values lesser than 0.05.

# %%
X_features = chef_new[['AVG_TIME_PER_SITE_VISIT','LARGEST_ORDER_SIZE','AVG_CLICKS_PER_VISIT','MASTER_CLASSES_ATTENDED','TOTAL_PHOTOS_VIEWED','MEDIAN_MEAL_RATING','TOTAL_MEALS_ORDERED','UNIQUE_MEALS_PURCH','AVG_PREP_VID_TIME']]
y_target = chef_new[['REVENUE']]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_features,
                                                    y_target,
                                                    test_size = 0.25,
                                                    random_state = 222)

# %%
from sklearn.linear_model import LinearRegression

# INSTANTIATING a model object
lr = LinearRegression()


# FITTING to the training data
lr_fit = lr.fit(X_features_df , y_target_df)


# PREDICTING on new data
lr_pred = lr_fit.predict(X_test)


# SCORING the results
print('Training Score:', lr.score(X_train, y_train).round(4))
print('Testing Score:',  lr.score(X_test, y_test).round(4))
# Out:
# Training Score: 0.6481
# Testing Score: 0.5789

# %% [markdown]
# We understood that from the above ols reg base model, the feature [total meals ordered]is relevant to the response or target variable. We observe that R-square value is 0.36 which is not closer to 1, so adding more features will
